# %%
import geopandas as gpd
import pandas as pd

# %%
stops=gpd.read_file('/Users/anastasiaclark/MyStaff/Git_Work/MTA-Mass-Transit/Sep2018/shapes/stops_nyc_subway_Sep2018.shp')

# %%
stops_may=gpd.read_file('/Users/anastasiaclark/MyStaff/Git_Work/MTA-Mass-Transit/stops_nyc_subway_may2019/stops_nyc_subway_may2019.shp')

# %%
stops_may.loc[pd.notnull(stops_may.stop_id2)]
# Out:
#     stop_id                    stop_name   stop_lat   stop_lon   trains  \
# 151     A12                       145 St  40.824783 -73.944216      A C
# 167     A32                       W 4 St  40.732338 -74.000495    A C E
# 295     D43  Coney Island - Stillwell Av  40.577422 -73.981233  D F N Q
# 404     718             Queensboro Plaza  40.750582 -73.940202        7
#
#     structure stop_id2  GEOID         NAMELSAD  \
# 151    Subway      D13  36061  New York County
# 167    Subway      D20  36061  New York County
# 295   Viaduct      N12  36047     Kings County
# 404  Elevated      R09  36081    Queens County
#
#                                         geometry
# 151  POINT (999688.8810202146 239772.8124536319)
# 167  POINT (984112.8125671004 206087.0594983613)
# 295  POINT (989463.2969787853 149647.4038180028)
# 404  POINT (1000818.257434258 212739.5831276691)

# %%
stops_may.columns
# Out:
# Index(['stop_id', 'stop_name', 'stop_lat', 'stop_lon', 'trains', 'structure',
#        'stop_id2', 'GEOID', 'NAMELSAD', 'geometry'],
#       dtype='object')

# %%
stops_jun=gpd.read_file('/Users/anastasiaclark/MyStaff/Git_Work/MTA-Mass-Transit/June2019/shapes/stops_nyc_subway_june2019.shp')

# %%
stops_jun.shape
# Out:
# (497, 16)

# %%
[stop_id for stop_id in stops_jun.stop_id.tolist() if stop_id not in stops_may.stop_id.tolist()]
# Out:
# ['140', 'H19', 'S10', 'S12']

# %%
stops_jun.loc[stops_jun.stop_id.isin(['140', 'H19', 'S10', 'S12'])]
# Out:
#     stop_id stop_code         stop_name stop_desc   stop_lat   stop_lon  \
# 104     140      None  South Ferry Loop      None  40.701411 -74.013205
# 456     H19      None     Broad Channel      None  40.609014 -73.816024
# 475     S10      None          Atlantic      None  40.515401 -74.245689
# 477     S12      None            Nassau      None  40.517812 -74.238373
#
#     zone_id stop_url  location_t parent_sta trains structure stop_id2  GEOID  \
# 104    None     None           1       None   None      None     None  36061
# 456    None     None           1       None   None      None     None  36081
# 475    None     None           1       None   None      None     None  36085
# 477    None     None           1       None   None      None     None  36085
#
#             NAMELSAD                                     geometry
# 104  New York County  POINT (980588.5841761361 194819.6842230781)
# 456    Queens County  POINT (1035332.600614185 161210.2559843885)
# ...

# %%
stops.loc[~stops.stop_id.isin(stops_may.stop_id.unique().tolist()), 'stop_id'].tolist()

# %%
stops_may2018=pd.read_csv('/Users/anastasiaclark/MyStaff/Git_Work/MTA-Mass-Transit/May2018/nyc_subway/stops.txt')

# %%
stops_may2018.loc[stops_may2018.stop_id.isin(['140', 'H19', 'S10', 'S12'])]
# Out:
#      stop_id  stop_code         stop_name  stop_desc   stop_lat   stop_lon  \
# 111      140        NaN  South Ferry Loop        NaN  40.701411 -74.013205
# 1086     H19        NaN     Broad Channel        NaN  40.609014 -73.816024
# 1437     S10        NaN          Atlantic        NaN  40.515401 -74.245689
# 1443     S12        NaN            Nassau        NaN  40.517812 -74.238373
#
#       zone_id  stop_url  location_type parent_station
# 111       NaN       NaN              1            NaN
# 1086      NaN       NaN              1            NaN
# 1437      NaN       NaN              1            NaN
# 1443      NaN       NaN              1            NaN

# %%
bus_rail=gpd.read_file('/Users/anastasiaclark/MyStaff/Git_Work/MTA-Mass-Transit/Sep2018/shapes/metro_north_bx_bus_Sep2018.shp')

# %%
bus_rail.head()
# Out:
#    stop_id                             stop_name   stop_lat   stop_lon  GEOID  \
# 0      502            Kappock St/Knolls Crescent  40.879135 -73.916842  36005
# 1      504    Henry Hudson Pkwy/Independence Ave  40.881049 -73.919170  36005
# 2      505  227th St/Henry Hudson Pkwy-East Side  40.881836 -73.917936  36005
# 3      506            232nd St/Henry Hudson Pkwy  40.884732 -73.914546  36005
# 4      507  235th St/Henry Hudson Pkwy-East Side  40.886127 -73.912400  36005
#
#        NAMELSAD                                     geometry
# 0  Bronx County  POINT (1007246.158052433 259581.3181720213)
# 1  Bronx County  POINT (1006601.739589655 260278.0619491932)
# 2  Bronx County  POINT (1006942.706134422 260565.1147141825)
# 3  Bronx County   POINT (1007879.09456679 261621.1396769463)
# 4  Bronx County  POINT (1008471.981809957 262129.9803015306)

# %%
lirr=gpd.read_file('/Users/anastasiaclark/MyStaff/Git_Work/MTA-Mass-Transit/Sep2018/shapes/stops_LIRR_Sep2018.shp')

# %%
lirr.head()
# Out:
#    stop_id            stop_name  stop_lat  stop_lon  GEOID       NAMELSAD  \
# 0        1     Long Island City  40.74128 -73.95639  36081  Queens County
# 1        2  Hunterspoint Avenue  40.74238 -73.94679  36081  Queens County
# 2        9             Woodside  40.74584 -73.90297  36081  Queens County
# 3       10         Forest Hills  40.71957 -73.84481  36081  Queens County
# 4       11          Kew Gardens  40.70964 -73.83089  36081  Queens County
#
#                                       geometry
# 0   POINT (996334.729001164 209347.9198687444)
# 1  POINT (998994.7328762955 209750.1549324456)
# 2  POINT (1011136.053891131 211021.1556908129)
# 3  POINT (1027268.557544581 201473.3875489176)
# 4  POINT (1031134.151348136 197862.7357058352)

# %%
bus=gpd.read_file('/Users/anastasiaclark/MyStaff/Git_Work/MTA-Mass-Transit/Sep2018/shapes/bus_stops_nyc_Sep2018.shp')

# %%
bus.head()
# Out:
#    stop_id                   stop_name   stop_lat   stop_lon  GEOID  \
# 0   100294      BRUCKNER BL/TREMONT AV  40.833150 -73.827630  36005
# 1   100296      BRUCKNER BL/KEARNEY AV  40.839142 -73.824818  36005
# 2   100298  MACDONOUGH PL/COUNTRY CLUB  40.842607 -73.825077  36005
# 3   101716    BAYCHESTER AV/ALDRICH ST  40.870415 -73.832488  36005
# 4   101717  BAYCHESTER AV/DONIZETTI PL  40.876173 -73.833697  36005
#
#        NAMELSAD                                     geometry
# 0  Bronx County  POINT (1031949.407765885 242863.2320205418)
# 1  Bronx County  POINT (1032723.196746612 245047.8794435479)
# 2  Bronx County  POINT (1032649.010098742 246310.1628801106)
# 3  Bronx County  POINT (1030579.107005887 256437.6590170595)
# 4  Bronx County  POINT (1030240.749229186 258534.8849715356)

# %%
rail_lines=gpd.read_file('/Users/anastasiaclark/MyStaff/Git_Work/MTA-Mass-Transit/routes_nyc_subway_may2019/routes_nyc_subway_may2019.shp')

# %%
rail_lines
# Out:
#    route_id route_shor                       route_long    color group  \
# 0         1          1        Broadway - 7 Avenue Local  #EE352E   123
# 1         2          2                 7 Avenue Express  #EE352E   123
# 2         3          3                 7 Avenue Express  #EE352E   123
# 3         4          4         Lexington Avenue Express  #00933C   456
# 4         5          5         Lexington Avenue Express  #00933C   456
# 5         6          6           Lexington Avenue Local  #00933C   456
# 6         7          7                   Flushing Local  #B933AD     7
# 7         A          A                 8 Avenue Express  #2850AD   ACE
# 8         B          B                 6 Avenue Express  #FF6319  BDFM
# 9         C          C                   8 Avenue Local  #2850AD   ACE
# 10        D          D                 6 Avenue Express  #FF6319  BDFM
# 11        E          E                   8 Avenue Local  #2850AD   ACE
# ...

# %%
metro=pd.read_csv('/Users/anastasiaclark/MyStaff/Git_Work/MTA-Mass-Transit/Nov2018/metro_north/shapes.txt')

# %%
metro.shape
# Out:
# (951, 5)

# %%
metro.duplicated(['shape_pt_lat', 'shape_pt_lon']).sum()
# Out:
# 809

# %%
metro_new=pd.read_csv('/Users/anastasiaclark/MyStaff/Git_Work/MTA-Mass-Transit/June2019/metro_north/shapes.txt')

# %%
metro_new.duplicated(['shape_pt_lat', 'shape_pt_lon']).sum()
# Out:
# 53590

# %%
metro_new.shape[0]-metro_new.duplicated(['shape_pt_lat', 'shape_pt_lon']).sum()
# Out:
# 14183

# %%
import os

# %%
os.path.exists('/Users/anastasiaclark/MyStaff/Git_Work/MTA-Mass-Transit/Nov2018')
# Out:
# True
